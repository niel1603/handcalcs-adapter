# %%
import forallpeople as fp
fp.environment("structural")

m   = fp.m
mm  = fp.mm
kN  = fp.kN
MPa = fp.MPa
GPa = fp.GPa

# %%
import handcalcs
from handcalcs import  render
handcalcs.set_option("param_columns", 1)

# %% [markdown]
# ## Design Load LRFD

# %%
# %%render param
# M_u = 860.9076 * kN * m
# T_u = 90.743688 * kN
# V_u = 203.728476 * kN
# V_uc = 87.185112 * kN
# Out:
# \[
# \begin{aligned}
# &M_{u} &= 860.908\ \mathrm{kN} \cdot \mathrm{m} \;
# \\[10pt]
#  &T_{u} &= 90.744\ \mathrm{kN} \;
# \\[10pt]
#  &V_{u} &= 203.728\ \mathrm{kN} \;
# \\[10pt]
#  &V_{uc} &= 87.185\ \mathrm{kN} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ## Material Properties

# %% [markdown]
# #### Steel

# %%
# %%render param
# E = 200 * GPa
# Out:
# \[
# \begin{aligned}
# &E &= 200.000\ \mathrm{GPa} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Beam and column

# %%
# %%render param
# F_ybc = 344.738 * MPa
# F_ubc = 448.1594 * MPa
# Out:
# \[
# \begin{aligned}
# &F_{ybc} &= 344.738\ \mathrm{MPa} \;
# \\[10pt]
#  &F_{ubc} &= 448.159\ \mathrm{MPa} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### End plate

# %%
# %%render param
# F_yp = 344.738 * MPa
# F_up = 448.1594 * MPa
# Out:
# \[
# \begin{aligned}
# &F_{yp} &= 344.738\ \mathrm{MPa} \;
# \\[10pt]
#  &F_{up} &= 448.159\ \mathrm{MPa} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Stiffener

# %%
# %%render param
# F_ys = 344.738 * MPa
# F_us = 448.1594 * MPa
# Out:
# \[
# \begin{aligned}
# &F_{ys} &= 344.738\ \mathrm{MPa} \;
# \\[10pt]
#  &F_{us} &= 448.159\ \mathrm{MPa} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Bolt

# %%
# %%render param
# F_nt = 779.10788 * MPa
# F_nv = 468.84368 * MPa
# Out:
# \[
# \begin{aligned}
# &F_{nt} &= 779.108\ \mathrm{MPa} \;
# \\[10pt]
#  &F_{nv} &= 468.844\ \mathrm{MPa} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Bolt pretension force

# %%
# %%render param
# T_b = 453.71844 * kN
# Out:
# \[
# \begin{aligned}
# &T_{b} &= 453.718\ \mathrm{kN} \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ## Geometry Properties

# %% [markdown]
# #### Beam

# %%
# %%render param
# d_b = 612.14 * mm # web height
# b_bf = 229.108 * mm # flange width
# t_bw = 11.938 * mm # web thick
# t_bf = 19.558 * mm # flange thick
# Out:
# \[
# \begin{aligned}
# &d_{b} &= 612.140\ \mathrm{mm} \; \;\textrm{(web height)}
# \\[10pt]
#  &b_{bf} &= 229.108\ \mathrm{mm} \; \;\textrm{(flange width)}
# \\[10pt]
#  &t_{bw} &= 11.938\ \mathrm{mm} \; \;\textrm{(web thick)}
# \\[10pt]
#  &t_{bf} &= 19.558\ \mathrm{mm} \; \;\textrm{(flange thick)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Column

# %%
# %%render param
# d_c = 360.68 * mm # web height
# b_cf = 370.84 * mm # flange width
# t_cw = 12.319 * mm # web thick
# t_cf = 19.812 * mm # flange thick
# k_des = 35.052 * mm # fillet distance used in production
# Out:
# \[
# \begin{aligned}
# &d_{c} &= 360.680\ \mathrm{mm} \; \;\textrm{(web height)}
# \\[10pt]
#  &b_{cf} &= 370.840\ \mathrm{mm} \; \;\textrm{(flange width)}
# \\[10pt]
#  &t_{cw} &= 12.319\ \mathrm{mm} \; \;\textrm{(web thick)}
# \\[10pt]
#  &t_{cf} &= 19.812\ \mathrm{mm} \; \;\textrm{(flange thick)}
# \\[10pt]
#  &k_{des} &= 35.052\ \mathrm{mm} \; \;\textrm{(fillet distance used in production)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### End plate

# %%
# %%render param
# b_p = 228.6 * mm # plate width
# t_p = 22.225 * mm # plate thickness
# Out:
# \[
# \begin{aligned}
# &b_{p} &= 228.600\ \mathrm{mm} \; \;\textrm{(plate width)}
# \\[10pt]
#  &t_{p} &= 22.225\ \mathrm{mm} \; \;\textrm{(plate thickness)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Bolt

# %%
# %%render param
# d_bolt = 31.75 * mm # bolt diameter
# d_hole = d_bolt + 3.175 * mm # hole diameter
# Out:
# \[
# \begin{aligned}
# &d_{bolt} &= 31.750\ \mathrm{mm} \; \;\textrm{(bolt diameter)}
# \\[10pt]
#  &d_{hole} &= 34.925\ \mathrm{mm} \; \;\textrm{(hole diameter)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Bolt configuration

# %%
# %%render param
# g = 146.05 * mm # bolt gauge
# p_ext = 114.3 * mm # top plate to beam
# d_e = 44.45 * mm # edge distance
# p_fo = 69.85 * mm # flange outer bolt
# p_fi = 50.8 * mm # flange inner bolt
# d_p = 841.375 * mm # bolt group height
# Out:
# \[
# \begin{aligned}
# &g &= 146.050\ \mathrm{mm} \; \;\textrm{(bolt gauge)}
# \\[10pt]
#  &p_{ext} &= 114.300\ \mathrm{mm} \; \;\textrm{(top plate to beam)}
# \\[10pt]
#  &d_{e} &= 44.450\ \mathrm{mm} \; \;\textrm{(edge distance)}
# \\[10pt]
#  &p_{fo} &= 69.850\ \mathrm{mm} \; \;\textrm{(flange outer bolt)}
# \\[10pt]
#  &p_{fi} &= 50.800\ \mathrm{mm} \; \;\textrm{(flange inner bolt)}
# \\[10pt]
#  &d_{p} &= 841.375\ \mathrm{mm} \; \;\textrm{(bolt group height)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### Stiffenert

# %%
# %%render param
# t_s = 12.7 * mm # stiffener thickness
# L_st = 203.2 * mm # stiffener length
# h_st = 114.3 * mm # stiffener height
# Out:
# \[
# \begin{aligned}
# &t_{s} &= 12.700\ \mathrm{mm} \; \;\textrm{(stiffener thickness)}
# \\[10pt]
#  &L_{st} &= 203.200\ \mathrm{mm} \; \;\textrm{(stiffener length)}
# \\[10pt]
#  &h_{st} &= 114.300\ \mathrm{mm} \; \;\textrm{(stiffener height)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# #### 1. The distance from the centerline of the compression flange to the bolt lines

# %% [markdown]
# 1.1 Calculate distance

# %%
# %%render
# h_1 = d_b - (t_bf / 2) + p_fo
# h_2 = d_b - (3 * t_bf / 2) - p_fi
# Out:
# \[
# \begin{aligned}
# h_{1} &= d_{b} - \left( \frac{ t_{bf} }{ 2 } \right) + p_{fo}  = 612.140\ \mathrm{mm} - \left( \frac{ 19.558\ \mathrm{mm} }{ 2 } \right) + 69.850\ \mathrm{mm} &= 672.211\ \mathrm{mm}
# \\[10pt]
# h_{2} &= d_{b} - \left( 3 \cdot \frac{ t_{bf} }{ 2 } \right) - p_{fi}  = 612.140\ \mathrm{mm} - \left( 3 \cdot \frac{ 19.558\ \mathrm{mm} }{ 2 } \right) - 50.800\ \mathrm{mm} &= 532.003\ \mathrm{mm}
# \end{aligned}
# \]

# %% [markdown]
# 1.2 Check base plate effective width

# %%
# %%render
# b_p_limit = b_bf + max(t_p, 25.4 * mm)
#
# if b_p <= b_p_limit : b_p_eff = b_p
# elif b_p > b_p_limit : b_p_eff = b_p_limit
# Out:
# \[
# \begin{aligned}
# b_{p_{limit}} &= b_{bf} + \operatorname{max} \left( t_{p} ,\  25.4 \cdot \mathrm{mm} \right)  = 229.108\ \mathrm{mm} + \operatorname{max} \left( 22.225\ \mathrm{mm} ,\  25.4 \cdot 1.000\ \mathrm{mm} \right) &= 254.508\ \mathrm{mm}
# \\[10pt]
# &\text{Since, } b_{p} \leq b_{p_{limit}} \rightarrow \left( 228.600\ \mathrm{mm} \leq 254.508\ \mathrm{mm} \right) :   \\[10pt]
# b_{p_{eff}} &= 228.600\ \mathrm{mm} \;
# \end{aligned}
# \]

# %% [markdown]
# 1.3 Check bolt gage

# %%
# %%render
# b_bf_limit = b_bf
#
# if b_bf >= b_bf_limit :
#     b_bf = b_bf_limit # OK
# elif b_bf < b_bf_limit : b_bf = b_bf_limit # NOT OK
# Out:
# \[
# \begin{aligned}
# b_{bf_{limit}} &= 229.108\ \mathrm{mm} \;
# \\[10pt]
# &\text{Since, } b_{bf} \geq b_{bf_{limit}} \rightarrow \left( 229.108\ \mathrm{mm} \geq 229.108\ \mathrm{mm} \right) :   \\[10pt]
# \\[10pt]
# b_{bf} &= 229.108\ \mathrm{mm} \; \;\textrm{(OK)}
# \end{aligned}
# \]
