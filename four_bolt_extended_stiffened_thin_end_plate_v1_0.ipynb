# %%
import math
import forallpeople as fp
from HANDCALCS.utils.units.structural_units_forallpeople import (
    SI, 
    US, 
    to_unit, 
    safe_sqrt
    )
from handcalcs import  render

# %% [markdown]
# ## Design Load LRFD

# %%
# %%render param
# M_u  = 860.9076 * SI.kN * SI.m
# T_u  = 90.743688 * SI.kN
# V_u  = 203.728476 * SI.kN
# V_uc = 87.185112 * SI.kN
# Out:
# \[
# \begin{aligned}
# M_{u} &= 860.908\ \mathrm{kN} \cdot \mathrm{m} \;
#  &T_{u} &= 90.744\ \mathrm{kN} \;
#  &V_{u} &= 203.728\ \mathrm{kN} \;
# \\[10pt]
#  V_{uc} &= 87.185\ \mathrm{kN} \;
# \end{aligned}
# \]

# %% [markdown]
# ## Material Properties

# %% [markdown]
# #### Steel

# %%
# %%render param
# E = 200 * SI.GPa
# Out:
# \[
# \begin{aligned}
# E &= 200.000\ \mathrm{GPa} \;
# \end{aligned}
# \]

# %% [markdown]
# #### Beam and column

# %%
# %%render param
# F_ybc = 344.738 * SI.MPa
# F_ubc = 448.1594 * SI.MPa
# Out:
# \[
# \begin{aligned}
# F_{ybc} &= 344.738\ \mathrm{MPa} \;
#  &F_{ubc} &= 448.159\ \mathrm{MPa} \;
# \end{aligned}
# \]

# %% [markdown]
# #### End plate

# %%
# %%render param
# F_yp = 344.738 * SI.MPa
# F_up = 448.1594 * SI.MPa
# Out:
# \[
# \begin{aligned}
# F_{yp} &= 344.738\ \mathrm{MPa} \;
#  &F_{up} &= 448.159\ \mathrm{MPa} \;
# \end{aligned}
# \]

# %% [markdown]
# #### Stiffener

# %%
# %%render param
# F_ys = 344.738 * SI.MPa
# F_us = 448.1594 * SI.MPa
# Out:
# \[
# \begin{aligned}
# F_{ys} &= 344.738\ \mathrm{MPa} \;
#  &F_{us} &= 448.159\ \mathrm{MPa} \;
# \end{aligned}
# \]

# %% [markdown]
# #### Bolt

# %%
# %%render param
# F_nt = 779.10788 * SI.MPa
# F_nv = 468.84368 * SI.MPa
# Out:
# \[
# \begin{aligned}
# F_{nt} &= 779.108\ \mathrm{MPa} \;
#  &F_{nv} &= 468.844\ \mathrm{MPa} \;
# \end{aligned}
# \]

# %% [markdown]
# #### Bolt pretension force

# %%
# %%render param
# T_b = 453.71844 * SI.kN
# Out:
# \[
# \begin{aligned}
# T_{b} &= 453.718\ \mathrm{kN} \;
# \end{aligned}
# \]
