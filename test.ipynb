# %%
import math
from math import sqrt
import handcalcs
from handcalcs import  render
handcalcs.set_option("param_columns", 1)

# %%
# %%render
# x = 25
# y = 2*x/5
# Out:
# \[
# \begin{aligned}
# x &= 25 \;
# \\[10pt]
# y &= 2 \cdot \frac{ x }{ 5 }  = 2 \cdot \frac{ 25 }{ 5 } &= 10.000
# \end{aligned}
# \]

# %%
# %%render
# if x <= 24: b = 2*x # OK
# elif x > 24: b = y # NOT OK
# Out:
# \[
# \begin{aligned}
# &\text{Since, } x \gt 24 \rightarrow \left( 25 \gt 24 \right) : \; \;\textrm{(NOT OK)} \\[10pt]
# b &= 10.000 \;
# \end{aligned}
# \]
